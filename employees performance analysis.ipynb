# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(42)

# %%
WH=np.random.randint(4,10,size=(31))

# %%
print(WH)
# Out:
# [7 8 6 8 8 5 6 6 6 8 7 6 9 8 5 7 9 9 5 7 8 4 7 5 9 8 7 4 4 6 6]

# %%
eid=[f'Eid{i}' for i in range(1,32)]
data={'employersID':eid,'Working_hrs':WH}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    employersID  Working_hrs
# 0         Eid1            7
# 1         Eid2            8
# 2         Eid3            6
# 3         Eid4            8
# 4         Eid5            8
# 5         Eid6            5
# 6         Eid7            6
# 7         Eid8            6
# 8         Eid9            6
# 9        Eid10            8
# 10       Eid11            7
# 11       Eid12            6
# 12       Eid13            9
# 13       Eid14            8
# 14       Eid15            5
# 15       Eid16            7
# 16       Eid17            9
# 17       Eid18            9
# 18       Eid19            5
# 19       Eid20            7
# 20       Eid21            8
# 21       Eid22            4
# 22       Eid23            7
# 23       Eid24            5
# 24       Eid25            9
# 25       Eid26            8
# 26       Eid27            7
# 27       Eid28            4
# 28       Eid29            4
# 29       Eid30            6
# 30       Eid31            6

# %%
c=df.describe()
d=df.head()
print(c,d)
# Out:
#        Working_hrs
# count    31.000000
# mean      6.709677
# std       1.531743
# min       4.000000
# 25%       6.000000
# 50%       7.000000
# 75%       8.000000
# max       9.000000   employersID  Working_hrs
# 0        Eid1            7
# 1        Eid2            8
# 2        Eid3            6
# 3        Eid4            8
# 4        Eid5            8

# %%
OT=df[df['Working_hrs']>8]
print(OT)
# Out:
#    employersID  Working_hrs
# 12       Eid13            9
# 16       Eid17            9
# 17       Eid18            9
# 24       Eid25            9

# %%
NT=df[df['Working_hrs']<5]
print(NT)
# Out:
#    employersID  Working_hrs
# 21       Eid22            4
# 27       Eid28            4
# 28       Eid29            4
# 7

# %%
#visualization of each employeee working hours
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(19,6))
sns.barplot(data=df,x='employersID',y='Working_hrs')
plt.title('working of hours of each employeee')
plt.tight_layout()
plt.show()

# %%
#visualization of employess with overtime and undertime hrs
summary = pd.DataFrame({
    'Category': ['NT', 'OT'],
    'Count': [ot_count,nt_count]
})

df
# Out:
#    employersID  Working_hrs
# 0         Eid1            7
# 1         Eid2            8
# 2         Eid3            6
# 3         Eid4            8
# 4         Eid5            8
# 5         Eid6            5
# 6         Eid7            6
# 7         Eid8            6
# 8         Eid9            6
# 9        Eid10            8
# 10       Eid11            7
# 11       Eid12            6
# 12       Eid13            9
# 13       Eid14            8
# 14       Eid15            5
# 15       Eid16            7
# 16       Eid17            9
# 17       Eid18            9
# 18       Eid19            5
# 19       Eid20            7
# 20       Eid21            8
# 21       Eid22            4
# 22       Eid23            7
# 23       Eid24            5
# 24       Eid25            9
# 25       Eid26            8
# 26       Eid27            7
# 27       Eid28            4
# 28       Eid29            4
# 29       Eid30            6
# 30       Eid31            6

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=summary,x='Count',y='Category',hue='Count',palette='Set2')
# Out:
# <Axes: xlabel='Count', ylabel='Category'>
